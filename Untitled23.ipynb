# %%
tup=1,2,3

# %%
type(tup)
# Out:
# tuple

# %%
abc=100,00,00

# %%
abc
# Out:
# (100, 0, 0)

# %%
type(abc)
# Out:
# tuple

# %%
import numpy as np
import pandas as pd

# %%
df_movie= pd.read_csv("C:/Users/JAY KUMAR/Downloads/movie_data/movies.csv")

# %%
df_movie
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df_movie.shape
# Out:
# (9742, 3)

# %%
df_movie["movieId"].nunique()
# Out:
# 9742

# %%
df_rating= pd.read_csv("C:/Users/JAY KUMAR/Downloads/movie_data/ratings.csv")

# %%
df_rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df_rating["userId"].nunique()
# Out:
# 610

# %%
df_rating["movieId"].nunique()
# Out:
# 9724

# %%
df_links= pd.read_csv("C:/Users/JAY KUMAR/Downloads/movie_data/links.csv")

# %%
df_links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
df_rating.shape
# Out:
# (100836, 4)

# %%
df_links["movieId"].nunique()
# Out:
# 9742

# %%
df_tags= pd.read_csv("C:/Users/JAY KUMAR/Downloads/movie_data/tags.csv")

# %%
df_tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
df_tags["movieId"].nunique()
# Out:
# 1572

# %%
df_rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df_g_movie_id= df_rating.groupby("movieId")

# %%
df_rating.loc[df_g_movie_id["rating"].count().idxmax()]
# Out:
# userId               4.0
# movieId            919.0
# rating               5.0
# timestamp    945079521.0
# Name: 356, dtype: float64

# %%
df_rating.loc[356]
# Out:
# userId               4.0
# movieId            919.0
# rating               5.0
# timestamp    945079521.0
# Name: 356, dtype: float64

# %%
df_movie.loc[df_movie["movieId"]==919]
# Out:
#      movieId                     title                              genres
# 701      919  Wizard of Oz, The (1939)  Adventure|Children|Fantasy|Musical

# %%
df_movie_rating= pd.merge(df_movie,df_rating,on="movieId")

# %%
df_movie_rating
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
df_movie_rating

# %%
df_movie.duplicated().sum()
# Out:
# 0

# %%
df_movie_tags= pd.merge(df_movie,df_tags,on="movieId")

# %%
df_movie_tags
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 1           1                Toy Story (1995)
# 2           1                Toy Story (1995)
# 3           2                  Jumanji (1995)
# 4           2                  Jumanji (1995)
# ...       ...                             ...
# 3678   187595  Solo: A Star Wars Story (2018)
# 3679   193565       Gintama: The Movie (2010)
# 3680   193565       Gintama: The Movie (2010)
# 3681   193565       Gintama: The Movie (2010)
# 3682   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     336             pixar
# 1     Adventure|Animation|Children|Comedy|Fantasy     474             pixar
# 2     Adventure|Animation|Children|Comedy|Fantasy     567               fun
# 3                      Adventure|Children|Fantasy      62           fantasy
# ...

# %%
df_movie_tags.loc[df_movie_tags["title"]=="Matrix, The (1999)"]
# Out:
#       movieId               title                  genres  userId  \
# 1313     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1314     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     424
# 1315     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     474
# 1316     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
# 1317     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller     537
#
#                      tag   timestamp
# 1313        martial arts  1457842912
# 1314              sci-fi  1457842899
# 1315  alternate universe  1137204991
# 1316          philosophy  1424141098
# 1317    post apocalyptic  1424141101

# %%
df_movie_rating
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
"Terminator 2: Judgment Day (1991)"

# %%
df_movie_rating.loc[df_movie_rating["title"]=="Terminator 2: Judgment Day (1991)","rating"].mean()
# Out:
# 3.970982142857143

# %%
"Fight Club (1999)"

# %%
df_movie_rating.loc[df_movie_rating["title"]=="Fight Club (1999)","rating"].mean()
# Out:
# 4.272935779816514

# %%
fight_rat=df_movie_rating.loc[df_movie_rating["title"]=="Fight Club (1999)","rating"]

# %%
fight_rat
# Out:
# 49835    5.0
# 49836    2.0
# 49837    0.5
# 49838    2.5
# 49839    3.5
#         ...
# 50048    5.0
# 50049    4.0
# 50050    5.0
# 50051    5.0
# 50052    5.0
# Name: rating, Length: 218, dtype: float64

# %%
type(fight_rat)
# Out:
# pandas.core.series.Series

# %%
df_rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df_g_movieid= df_rating.groupby("movieId")['rating'].agg

# %%
df_g_movieid.agg({"rating":['mean','count']})
# Out:
#            rating
#              mean count
# movieId
# 1        3.920930   215
# 2        3.431818   110
# 3        3.259615    52
# 4        2.357143     7
# 5        3.071429    49
# ...           ...   ...
# 193581   4.000000     1
# 193583   3.500000     1
# 193585   3.500000     1
# 193587   3.500000     1
# 193609   4.000000     1
#
# [9724 rows x 2 columns]

# %%
m_c=df_g_movieid.agg({"rating":['mean','count']})

# %%
df_g_movieid["rating"].count()
# Out:
# movieId
# 1         215
# 2         110
# 3          52
# 4           7
# 5          49
#          ...
# 193581      1
# 193583      1
# 193585      1
# 193587      1
# 193609      1
# Name: rating, Length: 9724, dtype: int64

# %%
df_inn=pd.merge(df_movie,df_g_movieid,on="movieId")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df_inn=pd.merge(df_movie,df_g_movieid,on="movieId")
#
# File ~\anaconda3\envs\jaya\lib\site-packages\pandas\core\reshape\merge.py:148, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#     152         on=on,
#     153         left_on=left_on,
#     154         right_on=right_on,
#     155         left_index=left_index,
#     156         right_index=right_index,
#     157         sort=sort,
# ...

# %%
group = df_movie_rating.groupby('movieId')['rating'].agg(['count','mean'])

# %%
group
# Out:
#          count      mean
# movieId
# 1          215  3.920930
# 2          110  3.431818
# 3           52  3.259615
# 4            7  2.357143
# 5           49  3.071429
# ...        ...       ...
# 193581       1  4.000000
# 193583       1  3.500000
# 193585       1  3.500000
# 193587       1  3.500000
# 193609       1  4.000000
#
# [9724 rows x 2 columns]

# %%
ratings_group=group[group['count']>50]

# %%
ratings_group
# Out:
#          count      mean
# movieId
# 1          215  3.920930
# 2          110  3.431818
# 3           52  3.259615
# 6          102  3.946078
# 7           54  3.185185
# ...        ...       ...
# 106782      54  3.916667
# 109374      52  3.778846
# 109487      73  3.993151
# 112852      59  4.050847
# 122904      54  3.833333
#
# [436 rows x 2 columns]

# %%
movies_data=pd.merge(df_movie_rating,ratings_group,left_on="movieId",right_index=True)

# %%
movies_data
# Out:
#        movieId             title                                       genres  \
# 0            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4            1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# ...        ...               ...                                          ...
# 98310   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98311   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98312   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98313   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
# 98314   122904   Deadpool (2016)               Action|Adventure|Comedy|Sci-Fi
#
# ...

# %%
group = df_rating.groupby('movieId')['rating'].agg(['count','mean'])

# %%
group
# Out:
#          count      mean
# movieId
# 1          215  3.920930
# 2          110  3.431818
# 3           52  3.259615
# 4            7  2.357143
# 5           49  3.071429
# ...        ...       ...
# 193581       1  4.000000
# 193583       1  3.500000
# 193585       1  3.500000
# 193587       1  3.500000
# 193609       1  4.000000
#
# [9724 rows x 2 columns]

# %%
type(group)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data=pd.merge(df_movie,group,left_on="movieId",right_index=True)

# %%
movies_data
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  count      mean
# 0     Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                      Adventure|Children|Fantasy    110  3.431818
# 2                                  Comedy|Romance     52  3.259615
# ...

# %%
df_movie_50=movies_data.loc[movies_data["count"]>50]

# %%
df_movie_50
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 1           2                    Jumanji (1995)
# 2           3           Grumpier Old Men (1995)
# 5           6                       Heat (1995)
# 6           7                    Sabrina (1995)
# ...       ...                               ...
# 8305   106782   Wolf of Wall Street, The (2013)
# 8372   109374  Grand Budapest Hotel, The (2014)
# 8376   109487               Interstellar (2014)
# 8475   112852    Guardians of the Galaxy (2014)
# 8691   122904                   Deadpool (2016)
#
#                                            genres  count      mean
# 0     Adventure|Animation|Children|Comedy|Fantasy    215  3.920930
# 1                      Adventure|Children|Fantasy    110  3.431818
# 2                                  Comedy|Romance     52  3.259615
# 5                           Action|Crime|Thriller    102  3.946078
# ...

# %%
df_movie_50.loc[df_movie_50["mean"].idxmax()]
# Out:
# movieId                                 318
# title      Shawshank Redemption, The (1994)
# genres                          Crime|Drama
# count                                   317
# mean                               4.429022
# Name: 277, dtype: object

# %%
df_movie_50.sort_values(by="count",ascending=False)
# Out:
#       movieId                             title  \
# 314       356               Forrest Gump (1994)
# 277       318  Shawshank Redemption, The (1994)
# 257       296               Pulp Fiction (1994)
# 510       593  Silence of the Lambs, The (1991)
# 1939     2571                Matrix, The (1999)
# ...       ...                               ...
# 3152     4239                       Blow (2001)
# 3495     4776               Training Day (2001)
# 3544     4848           Mulholland Drive (2001)
# 118       145                   Bad Boys (1995)
# 1236     1645       The Devil's Advocate (1997)
#
#                                       genres  count      mean
# 314                 Comedy|Drama|Romance|War    329  4.164134
# 277                              Crime|Drama    317  4.429022
# 257              Comedy|Crime|Drama|Thriller    307  4.197068
# 510                    Crime|Horror|Thriller    279  4.161290
# 1939                  Action|Sci-Fi|Thriller    278  4.192446
# ...

# %%
df_movie_50.loc[df_movie_50["genres"].str.contains("Sci-Fi")].sort_values(by="count",ascending=False)
# Out:
#       movieId                                              title  \
# 1939     2571                                 Matrix, The (1999)
# 224       260          Star Wars: Episode IV - A New Hope (1977)
# 418       480                               Jurassic Park (1993)
# 507       589                  Terminator 2: Judgment Day (1991)
# 898      1196  Star Wars: Episode V - The Empire Strikes Back...
# ...       ...                                                ...
# 8691   122904                                    Deadpool (2016)
# 144       172                             Johnny Mnemonic (1995)
# 2029     2701                              Wild Wild West (1999)
# 559       673                                   Space Jam (1996)
# 6209    45499                       X-Men: The Last Stand (2006)
#
#                                                  genres  count      mean
# 1939                             Action|Sci-Fi|Thriller    278  4.192446
# ...

# %%
df_top_links= pd.merge(df_movie_50,df_links,on="movieId")

# %%
df_top_links
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...

# %%
df_links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
import requests

from bs4 import BeautifulSoup

# %%
URL="https://www.imdb.com/title/tt0114709/ratings/?ref_=tt_ov_rt"

# %%
request_header={"Content-Type": "text/plain;charset=UTF-8",
                "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
                "Accept-Encoding": "gzip, deflate, br"}

# %%
response=requests.get(URL,headers=request_header)

print(response.status_code)
# Out:
# 200

# %%
html_code = response.text

# %%
soup= BeautifulSoup(html_code)

# %%
title= soup.find("span" , attrs={"class": "sc-5931bdee-1 gVydpF"})

print(type(title))

print(title.text)
# Out:
# <class 'bs4.element.Tag'>
# 8.3

# %%
imdbid=df_top_links["imdbId"]

# %%
l1=[]
for i in imdbid:
    l1.append(i)

# %%
l1
# Out:
# [114709,
#  113497,
#  113228,
#  113277,
#  114319,
#  113189,
#  112346,
#  112641,
#  114388,
#  112281,
#  113161,
#  113627,
#  114746,
#  112431,
#  112818,
#  112697,
#  114369,
#  114148,
#  114814,
#  113862,
#  116367,
#  115759,
#  116483,
#  112573,
#  75314,
#  115685,
#  112442,
#  112384,
#  112462,
#  112642,
#  112715,
#  112740,
#  112851,
#  112864,
#  113071,
#  113481,
#  113492,
#  113957,
#  114898,
#  109445,
#  109635,
#  109686,
#  109707,
#  110148,
#  76759,
#  110322,
#  110632,
#  114069,
#  110413,
#  110912,
#  110932,
#  111282,
#  111070,
#  111161,
#  111280,
#  108550,
#  114924,
#  109040,
#  109444,
#  109446,
#  109506,
#  109830,
#  109831,
#  110357,
#  110475,
#  110478,
#  110622,
#  111257,
#  111503,
#  106220,
#  109254,
#  109439,
#  106582,
#  106598,
#  106673,
#  106697,
#  106918,
#  106977,
#  107144,
#  107206,
#  107290,
#  107362,
#  107614,
#  107818,
#  107822,
#  107977,
#  108052,
#  108160,
#  83658,
#  107688,
#  108333,
# ...

# %%
rat=[]

for i in l1:
    url=f"https://www.imdb.com/title/tt0{i}/ratings/?ref_=tt_ov_rt".format(i)
    request_header={"Content-Type": "text/plain;charset=UTF-8",
                    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
                    "Accept-Encoding": "gzip, deflate, br"}
   
    response = requests.get(url,headers=request_header)
    html_code = response.text
    
    soup = BeautifulSoup(html_code)
    
    title= soup.find("span" , attrs={"class": "sc-5931bdee-1 gVydpF"})
    if title is None:
      rat.append(np.NaN)
    else:
      rat.append(title.text)
      print(title.text)
# Out:
# 8.3
# 7.1
# 6.6
# 8.3
# 6.3
# 7.2
# 6.8
# 8.2
# 7.7
# 6.4
# 6.9
# 7.5
# 8.0
# 6.9
# 7.5
# 6.9
# 8.6
# 6.7
# 8.5
# 7.3
# 7.2
# 6.1
# 7.0
# 8.3
# 7.2
# 6.8
# 7.7
# 5.4
# 6.2
# 5.3
# 7.3
# 7.1
# 7.6
# 6.0
# 5.6
# 5.6
# 6.0
# 6.3
# 7.7
# 6.2
# 7.3
# 7.8
# 7.5
# 7.5
# 7.2
# 6.6
# 8.5
# 8.9
# 7.5
# 7.0
# 6.6
# 9.3
# 6.6
# 7.7
# 6.8
# 6.9
# 6.9
# 6.7
# 7.5
# 8.8
# 7.1
# 8.5
# 6.9
# 7.0
# 6.5
# 7.3
# 7.3
# 6.8
# 5.5
# 5.6
# 6.5
# 5.4
# 6.9
# 6.7
# 6.9
# 7.8
# 6.6
# 7.2
# 8.2
# 6.5
# 7.1
# 7.7
# 7.5
# 6.7
# 9.0
# 6.8
# 7.9
# 6.4
# 7.8
# 7.9
# 8.0
# 8.6
# 8.6
# 8.0
# 7.1
# 8.1
# 7.2
# 6.4
# 6.5
# 6.3
# 7.4
# 6.5
# 8.1
# 7.0
# 6.1
# 6.2
# 5.7
# 8.3
# 8.3
# 7.4
# 8.0
# 7.6
# 7.1
# 6.4
# 7.3
# 7.4
# 7.7
# 6.9
# 7.3
# 7.0
# 7.6
# 6.5
# 6.9
# 7.3
# 7.3
# 7.5
# 6.5
# 8.2
# 7.7
# 7.2
# 7.2
# 7.5
# 7.7
# 7.3
# 8.2
# 8.3
# 7.9
# 8.1
# 6.9
# 7.7
# 6.7
# 7.1
# 6.8
# 8.6
# 7.1
# 7.7
# 7.6
# 7.5
# 8.6
# 8.5
# 7.3
# 7.2
# 7.6
# 7.1
# 7.6
# 8.1
# 8.7
# 7.3
# 7.3
# 7.1
# 6.5
# 7.2
# 6.6
# 7.7
# 7.7
# 4.9
# ...

# %%
rat
# Out:
# ['8.3',
#  '7.1',
#  '6.6',
#  '8.3',
#  '6.3',
#  '7.2',
#  '6.8',
#  '8.2',
#  '7.7',
#  '6.4',
#  '6.9',
#  '7.5',
#  '8.0',
#  '6.9',
#  '7.5',
#  '6.9',
#  '8.6',
#  '6.7',
#  '8.5',
#  '7.3',
#  '7.2',
#  '6.1',
#  '7.0',
#  '8.3',
#  nan,
#  '7.2',
#  '6.8',
#  '7.7',
#  '5.4',
#  '6.2',
#  '5.3',
#  '7.3',
#  '7.1',
#  '7.6',
#  '6.0',
#  '5.6',
#  '5.6',
#  '6.0',
#  '6.3',
#  '7.7',
#  '6.2',
#  '7.3',
#  '7.8',
#  '7.5',
#  nan,
#  '7.5',
#  '7.2',
#  '6.6',
#  '8.5',
#  '8.9',
#  '7.5',
#  '7.0',
#  '6.6',
#  '9.3',
#  '6.6',
#  '7.7',
#  '6.8',
#  '6.9',
#  '6.9',
#  '6.7',
#  '7.5',
#  '8.8',
#  '7.1',
#  '8.5',
#  '6.9',
#  '7.0',
#  '6.5',
#  '7.3',
#  '7.3',
#  '6.8',
#  '5.5',
#  '5.6',
#  '6.5',
#  '5.4',
#  '6.9',
#  '6.7',
#  '6.9',
#  '7.8',
#  '6.6',
#  '7.2',
#  '8.2',
#  '6.5',
#  '7.1',
#  '7.7',
#  '7.5',
#  '6.7',
#  '9.0',
#  '6.8',
#  nan,
#  '7.9',
#  '6.4',
#  '7.8',
#  '7.9',
#  nan,
#  nan,
#  '8.0',
#  '8.6',
#  nan,
#  nan,
#  '8.6',
#  nan,
# ...

# %%
df_top_links
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...

# %%
df_top_links["imdbrating"]=pd.Series(rat)

# %%
df_top_links
# Out:
#      movieId                             title  \
# 0          1                  Toy Story (1995)
# 1          2                    Jumanji (1995)
# 2          3           Grumpier Old Men (1995)
# 3          6                       Heat (1995)
# 4          7                    Sabrina (1995)
# ..       ...                               ...
# 431   106782   Wolf of Wall Street, The (2013)
# 432   109374  Grand Budapest Hotel, The (2014)
# 433   109487               Interstellar (2014)
# 434   112852    Guardians of the Galaxy (2014)
# 435   122904                   Deadpool (2016)
#
#                                           genres  count      mean   imdbId  \
# 0    Adventure|Animation|Children|Comedy|Fantasy    215  3.920930   114709
# 1                     Adventure|Children|Fantasy    110  3.431818   113497
# 2                                 Comedy|Romance     52  3.259615   113228
# 3                          Action|Crime|Thriller    102  3.946078   113277
# ...
